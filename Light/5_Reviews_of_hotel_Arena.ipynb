# %% [markdown]
# Find the number of rows for each review score earned by 'Hotel Arena'. Output the hotel name (which should be 'Hotel Arena'), review score along with the corresponding number of rows with that score for the specified hotel.

# %%
import pandas as pd
import numpy as np

# %%
hotel_reviews = pd.read_csv("CSV/hotel_reviews.csv")
hotel_reviews.head()
# Out:
#                                        hotel_address  \
# 0  7 Western Gateway Royal Victoria Dock Newham L...
# 1  35 Charles Street Mayfair Westminster Borough ...
# 2        14 Rue Stanislas 6th arr 75006 Paris France
# 3  Gran V a De Les Corts Catalanes 570 Eixample 0...
# 4  Rathausstra e 17 01 Innere Stadt 1010 Vienna A...
#
#    additional_number_of_scoring review_date  average_score  \
# 0                           359  2017-07-05            8.5
# 1                           252  2015-08-29            9.1
# 2                            40  2017-05-23            9.1
# 3                           325  2016-08-25            8.2
# 4                           195  2015-09-17            8.5
#
#                              hotel_name      reviewer_nationality  \
# 0                  Novotel London Excel            United Kingdom
# 1              The Chesterfield Mayfair                    Israel
# 2                          Hotel Le Six  United States of America
# 3                       Sunotel Central            United Kingdom
# 4  Austria Trend Hotel Rathauspark Wien            United Kingdom
#
#                                      negative_review  \
# 0  coffee and tea at breakfast were not particula...
# 1                                        No Negative
# 2  There is currently utility construction taking...
# 3  Coffee at breakfast could be better When you s...
# 4                 A bit out of the way location wise
#
#    review_total_negative_word_counts  total_number_of_reviews  \
# 0                                 16                     1158
# 1                                  0                     1166
# 2                                 27                      177
# 3                                 22                     3870
# 4                                  9                     1884
#
#                                      positive_review  \
# 0  we were allocated the newly refurbished rooms ...
# 1  We liked everything The hotel is simply a bout...
# 2  Neat boutique hotel Some of the most comfortab...
# 3  Great bed nice to have a coffee machine in the...
# 4      Clean modern rooms and bathroom well equipped
#
#    review_total_positive_word_counts  \
# 0                                 34
# 1                                 41
# 2                                 39
# 3                                 26
# 4                                  9
#
#    total_number_of_reviews_reviewer_has_given  reviewer_score  \
# 0                                           2            10.0
# 1                                           8            10.0
# 2                                           3             9.2
# 3                                           2             9.2
# 4                                           2             7.5
#
#                                                 tags days_since_review  \
# 0  [' Leisure trip ', ' Family with young childre...           29 days
# 1  [' Leisure trip ', ' Couple ', ' Classic Doubl...           705 day
# 2  [' Leisure trip ', ' Family with young childre...           72 days
# 3  [' Leisure trip ', ' Group ', ' Comfort Double...           343 day
# 4  [' Leisure trip ', ' Couple ', ' Comfort Room ...           686 day
#
#       lat     lng
# 0  51.508   0.023
# 1  51.508  -0.147
# 2  48.844   2.328
# 3  41.384   2.162
# 4  48.213  16.357

# %%
arena = hotel_reviews[hotel_reviews['hotel_name'] == 'Hotel Arena']
arena.head()
# Out:
#                                         hotel_address  \
# 16  s Gravesandestraat 55 Oost 1092 AA Amsterdam N...
# 71  s Gravesandestraat 55 Oost 1092 AA Amsterdam N...
# 72  s Gravesandestraat 55 Oost 1092 AA Amsterdam N...
# 73  s Gravesandestraat 55 Oost 1092 AA Amsterdam N...
# 74  s Gravesandestraat 55 Oost 1092 AA Amsterdam N...
#
#     additional_number_of_scoring review_date  average_score   hotel_name  \
# 16                           194  2016-12-27            7.7  Hotel Arena
# 71                           194  2015-12-30            7.7  Hotel Arena
# 72                           194  2017-02-06            7.7  Hotel Arena
# 73                           194  2016-05-30            7.7  Hotel Arena
# 74                           194  2016-10-24            7.7  Hotel Arena
#
#         reviewer_nationality  \
# 16               Netherlands
# 71  United States of America
# 72                  Malaysia
# 73            United Kingdom
# 74                    France
#
#                                       negative_review  \
# 16                                     Breakfast poor
# 71                                        No Negative
# 72  The place is completely mismanaged The propert...
# 73                                        No Negative
# 74  Even allowing for the hotel being under major ...
#
#     review_total_negative_word_counts  total_number_of_reviews  \
# 16                                  4                     1403
# 71                                  0                     1403
# 72                                144                     1403
# 73                                  0                     1403
# 74                                119                     1403
#
#                         positive_review  review_total_positive_word_counts  \
# 16  Great hotel with beautiful interior                                  6
# 71                   location and staff                                  4
# 72            The property is beautiful                                  5
# 73                            breakfast                                  2
# 74                            Large bed                                  4
#
#     total_number_of_reviews_reviewer_has_given  reviewer_score  \
# 16                                          17             7.5
# 71                                           3             9.6
# 72                                           6             4.6
# 73                                           1             3.8
# 74                                          21             4.2
#
#                                                  tags days_since_review  \
# 16  [' Leisure trip ', ' Couple ', ' 2 rooms ', ' ...           219 day
# 71  [' Leisure trip ', ' Couple ', ' Duplex Double...           582 day
# 72  [' Leisure trip ', ' Group ', ' Duplex Twin Ro...           178 day
# 73  [' Leisure trip ', ' Family with older childre...           430 day
# 74  [' Leisure trip ', ' Couple ', ' Large King Ro...           283 day
#
#        lat    lng
# 16  52.361  4.916
# 71  52.361  4.916
# 72  52.361  4.916
# 73  52.361  4.916
# 74  52.361  4.916

# %%
result = arena.groupby(['reviewer_score','hotel_name']).size().to_frame('n_reviews').reset_index()
result
# Out:
#     reviewer_score   hotel_name  n_reviews
# 0              3.8  Hotel Arena          1
# 1              4.2  Hotel Arena          1
# 2              4.6  Hotel Arena          1
# 3              5.4  Hotel Arena          1
# 4              5.8  Hotel Arena          2
# 5              6.3  Hotel Arena          1
# 6              7.1  Hotel Arena          1
# 7              7.5  Hotel Arena          2
# 8              8.3  Hotel Arena          2
# 9              8.8  Hotel Arena          2
# 10             9.6  Hotel Arena          2
