# %% [markdown]
# Find the last time each bike was in use. Output both the bike number and the date-timestamp of the bike's last use (i.e., the date-time the bike was returned). Order the results by bikes that were most recently used.

# %%
import pandas as pd

# %%
dc_bikeshare_q1_2012 = pd.read_csv("CSV/dc_bikeshare_q1_2012.csv")
dc_bikeshare_q1_2012.head(10)
# Out:
#         duration  duration_seconds           start_time  \
# 0  0h 10m 47sec.               647  2012-03-25 10:30:00
# 1  0h 11m 45sec.               705  2012-03-28 18:59:00
# 2   0h 7m 45sec.               465  2012-03-12 22:30:00
# 3   0h 4m 27sec.               267  2012-03-12 20:11:00
# 4   0h 10m 2sec.               602  2012-02-03 09:06:00
# 5  0h 24m 59sec.              1499  2012-03-30 19:35:00
# 6  0h 13m 45sec.               825  2012-03-10 16:44:00
# 7  0h 12m 58sec.               778  2012-02-09 21:32:00
# 8    0h 2m 2sec.               122  2012-03-29 17:36:00
# 9  0h 17m 44sec.              1064  2012-02-18 08:43:00
#
#                                        start_station  start_terminal  \
# 0                              17th & Corcoran St NW           31214
# 1           Rosslyn Metro / Wilson Blvd & Ft Myer Dr           31015
# 2                                      3rd & H St NE           31616
# 3                                     14th & G St NW           31238
# 4                            Lamont & Mt Pleasant NW           31107
# 5  Eastern Market Metro / Pennsylvania Ave & 7th ...           31613
# 6                         North Capitol St & F St NW           31624
# 7                                     14th & R St NW           31202
# 8                                     18th & Bell St           31007
# 9                                     21st & I St NW           31205
#
#               end_time                           end_station  end_terminal  \
# 0  2012-03-25 10:40:00            Calvert St & Woodley Pl NW         31106
# 1  2012-03-28 19:11:00                        21st & M St NW         31212
# 2  2012-03-12 22:37:00                 Florida Ave & R St NW         31503
# 3  2012-03-12 20:15:00            14th & Rhode Island Ave NW         31203
# 4  2012-02-03 09:16:00            17th & Rhode Island Ave NW         31239
# 5  2012-03-30 20:00:00  Massachusetts Ave & Dupont Circle NW         31200
# 6  2012-03-10 16:58:00                         Thomas Circle         31241
# 7  2012-02-09 21:45:00                        18th & M St NW         31221
# 8  2012-03-29 17:38:00                     23rd & Crystal Dr         31011
# 9  2012-02-18 09:01:00                         8th & H St NW         31228
#
#   bike_number  rider_type      id
# 0      W00576  Registered  326188
# 1      W00011  Registered  345585
# 2      W01215  Registered  251919
# 3      W00455  Registered  251426
# 4      W00300  Registered  105965
# 5      W01352  Registered  357661
# 6      W00089  Registered  240483
# 7      W01158  Registered  129535
# 8      W00653  Registered  350819
# 9      W01398  Registered  156324

# %%
result = dc_bikeshare_q1_2012.groupby('bike_number')['end_time'].max().to_frame( 'last_used').reset_index().sort_values(by='last_used', ascending=False)
result
# Out:
#    bike_number            last_used
# 78      W01278  2012-03-31 19:28:00
# 65      W01097  2012-03-31 15:37:00
# 12      W00270  2012-03-31 12:10:00
# 61      W01006  2012-03-31 10:44:00
# 76      W01242  2012-03-31 09:24:00
# ..         ...                  ...
# 56      W00888  2012-01-10 14:17:00
# 9       W00191  2012-01-08 11:54:00
# 35      W00566  2012-01-07 21:04:00
# 18      W00380  2012-01-05 08:34:00
# 71      W01213  2012-01-01 01:23:00
#
# [98 rows x 2 columns]
