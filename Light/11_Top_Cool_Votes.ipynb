# %% [markdown]
# Find the review_text that received the highest number of  'cool' votes.
# Output the business name along with the review text with the highest numbef of 'cool' votes.

# %%
import pandas as pd
import numpy as np

# %%
yelp_reviews = pd.read_csv("CSV/yelp_reviews.csv")
yelp_reviews
# Out:
#             business_name               review_id                 user_id  \
# 0              AutohausAZ  C4TSIEcazRay0qIRPeMAFg  jlbPUcCRiXlMtarzi9sW5w
# 1    Citizen Public House  ZZ0paqUsSX-VJbfodTp1cQ  EeCWSGwMAPzwe_c1Aumd1w
# 2     Otto Pizza & Pastry  pF6W5JOPBK6kOXTB58cYrw  JG1Gd2mN2Qk7UpCqAUI-BQ
# 3        Giant Hamburgers  QBddRcflAcXwE2qhsLVv7w  T90ybanuLhAr0_s99GDeeg
# 4        Tammie Coe Cakes  Y8UMm_Ng9oEpJbIygoGbZQ  MWt24-6bfv_OHLKhwMQ0Tw
# ..                    ...                     ...                     ...
# 101     Maloney's on Shea  GsKuJK_VwyMCs8CEWRvmow  Ovpa3S8xD96dLE5eDxcxJg
# 102            China King  JrPq92qjI7yw1hik2JzwTw  uNbB1uR4EBhmygUc3IfPAw
# 103  Arriba Mexican Grill  Nagwfx92hDCamTkd7IUnYA  umFk-9qCmxsmiZw1e_vmKQ
# 104  Stacy's Pit Stop BBQ  0gl0HcuiebsHjTvUAYvzmA  gN03qFYysM5DbgjuV6N0QQ
# 105              Lunardis  fpjKqP8ONJ9rT8209thIQQ  9itypHULqGyO42s3zNUzOQ
#
#     stars review_date                                        review_text  \
# ...

# %%
result_cool = yelp_reviews[yelp_reviews['cool'] ==yelp_reviews['cool'].max()][['business_name','review_text','cool', 'funny', 'useful']]
result_cool
# Out:
#     business_name                                        review_text  cool  \
# 30      Roka Akor  I hate to admit it, but it had been a long whi...    10
# 105      Lunardis  This is the nicest grocery store in the city. ...    10
#
#      funny  useful
# 30       5       8
# 105      6       7

# %%
result_funny = yelp_reviews[yelp_reviews['funny'] ==yelp_reviews['funny'].max()][['business_name','review_text','funny', 'cool', 'useful']]
result_funny
# Out:
#                  business_name  \
# 20  Pappadeaux Seafood Kitchen
#
#                                           review_text  funny  cool  useful
# 20  $20 for a double Maker's Mark? Me thinks not T...     13     6       6

# %%
result_useful= yelp_reviews[yelp_reviews['useful'] ==yelp_reviews['useful'].max()][['business_name','review_text','useful', 'cool', 'funny']]
result_funny
# Out:
#                  business_name  \
# 20  Pappadeaux Seafood Kitchen
#
#                                           review_text  funny  cool  useful
# 20  $20 for a double Maker's Mark? Me thinks not T...     13     6       6
